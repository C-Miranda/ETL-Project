# %%
#Import dependencies
import pandas as pd

# Create a reference to the CSV and import it into a Pandas DataFrame
csv_path = "rec.csv"
rec_df = pd.read_csv(csv_path)

# %%
#Check df file for correct download
#del rec_df['regulatory_agency']
#del rec_df['products_permitted']
#del rec_df['cultivation_restrictions']
#del rec_df['retail_sales_on_premises']
#del rec_df['retail_sales_off_premises']
#del rec_df['pricing_controls_imposed']
#del rec_df['tax_imposed']
#del rec_df['impaired_driving_prohibitions']
#del rec_df['citations_count']
#del rec_df['juris_note']
#del rec_df['row_note']
#del rec_df['underage_prohibitions']
rec_df.head()
# Out:
#   jurisdiction date_begin     date_end recreational_use_legalized  \
# 0      Alaska    1/1/2012    2/23/2015                        NaN
# 1      Alaska   2/24/2015     5/4/2015                        Yes
# 2      Alaska    5/5/2015    2/20/2016                        Yes
# 3      Alaska   2/21/2016    5/27/2016                        Yes
# 4      Alaska   5/28/2016   12/31/2018                        Yes
#
#   local_authority                                          citations
# 0             NaN                                                NaN
# 1            Both  Enacted Bill: 2014 Alaska Ballot Measure No. 2...
# 2            Both  Enacted Bill: 2015 Alaska Sess. Laws 4\n<br><b...
# 3            Both  Enacted Bill: 2015 Alaska Sess. Laws 4\n<br><b...
# 4            Both  Enacted Bill: 2015 Alaska Sess. Laws 4\n<br><b...

# %%
rec_df.dropna
# Out:
# <bound method DataFrame.dropna of              jurisdiction  date_begin     date_end recreational_use_legalized  \
# 0                 Alaska     1/1/2012    2/23/2015                        NaN
# 1                 Alaska    2/24/2015     5/4/2015                        Yes
# 2                 Alaska     5/5/2015    2/20/2016                        Yes
# 3                 Alaska    2/21/2016    5/27/2016                        Yes
# 4                 Alaska    5/28/2016   12/31/2018                        Yes
# 5                 Alaska     1/1/2019     1/1/2019                        Yes
# 6             California     1/1/2012    11/8/2016                        NaN
# 7             California    11/9/2016    6/26/2017                        Yes
# 8             California    6/27/2017    12/6/2017                        Yes
# 9             California    12/7/2017   12/31/2017                        Yes
# 10            California     1/1/2018     1/1/2019                        Yes
# ...

# %%
#Transfer csv file (df) as an html document
html= rec_df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>jurisdiction</th>
#       <th>date_begin</th>
#       <th>date_end</th>
#       <th>recreational_use_legalized</th>
#       <th>local_authority</th>
#       <th>citations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alaska</td>
#       <td>1/1/2012</td>
#       <td>2/23/2015</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alaska</td>
#       <td>2/24/2015</td>
#       <td>5/4/2015</td>
#       <td>Yes</td>
#       <td>Both</td>
# ...

# %%
#Transfer csv file (df) as an html document
html= rec_df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>jurisdiction</th>
#       <th>date_begin</th>
#       <th>date_end</th>
#       <th>recreational_use_legalized</th>
#       <th>local_authority</th>
#       <th>citations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alaska</td>
#       <td>1/1/2012</td>
#       <td>2/23/2015</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alaska</td>
#       <td>2/24/2015</td>
#       <td>5/4/2015</td>
#       <td>Yes</td>
#       <td>Both</td>
# ...

# %%
#Write html to a file for use on webpage 
rec_df.to_html('tablec.html')

#Assign to a string for easy access
htmltable = rec_df.to_html()

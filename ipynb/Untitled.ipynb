# %%
#Import dependencies
import pandas as pd

# Create a reference to the CSV and import it into a Pandas DataFrame
csv_path = "states_status.csv"
states_df = pd.read_csv(csv_path)

# %%
#Check df file for correct download
states_df.head()
# Out:
#         state medical recreational illegal
# 0     Alabama      no           no     yes
# 1      Alaska      no          yes      no
# 2     Arizona     yes           no      no
# 3    Arkansas     yes           no      no
# 4  California      no          yes      no

# %%
#Transfer csv file (df) as an html document
html= states_df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>medical</th>
#       <th>recreational</th>
#       <th>illegal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alabama</td>
#       <td>no</td>
#       <td>no</td>
#       <td>yes</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alaska</td>
#       <td>no</td>
#       <td>yes</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Arizona</td>
#       <td>yes</td>
#       <td>no</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Arkansas</td>
#       <td>yes</td>
#       <td>no</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>California</td>
#       <td>no</td>
#       <td>yes</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Colorado</td>
#       <td>no</td>
#       <td>yes</td>
# ...

# %%
#Write html to a file for use on webpage 
states_df.to_html('table.html')

#Assign to a string for easy access
htmltable = states_df.to_html()
